# %%
#Link:()
#1.
import pandas as pd
Customers=pd.DataFrame({
    'id':[1,2,3,4], 'name':['joe','Henry','jam','max']      
})
Orders=pd.DataFrame({
    'id':[1,2],'customerId':[3,1]
})
list1=[]
for id in Customers['id']:
    for customerid in Orders['customerId']:
        if id==customerid:
            Customers['count']=1

# %%
#Link:()
#2.

# %%
#Link:()
#3.

# %%
#Link:()
#4.

# %%
#Link:()
#5.
